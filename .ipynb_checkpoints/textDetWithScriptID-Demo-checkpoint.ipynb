# %% [markdown]
# # Python2 Notebook for Text Detection in Scene or Document

# %%
# %matplotlib inline
import keras
import tensorflow as tf
import numpy as np 
import cv2
from matplotlib import pyplot
import os
import sys
np.set_printoptions(3, suppress=True)
print "keras.version =", keras.__version__
print "tensorflow.version =", tf.__version__
# Out:
# Using TensorFlow backend.
# keras.version = 2.0.7
# tensorflow.version = 1.1.0

# %% [markdown]
# # Set Text Detection Path

# %%
repo_root = '/nas/medifor/yue_wu/thirdparty/TextDetWithScriptID/'
assert os.path.isdir( repo_root ), "ERROR: can't locate git repo for text detection"
model_dir = os.path.join( repo_root, 'model' )
scriptID_weight = os.path.join( model_dir, 'sciptIDModel.h5' )
assert os.path.isfile( scriptID_weight ), "ERROR: can't locate script-ID classification model"
textDet_weight  = os.path.join( model_dir, 'textDetModel.h5' )
assert os.path.isfile( textDet_weight ), "ERROR: can't locate text detection model"

data_dir  = os.path.join( repo_root, 'data' )
lib_dir   = os.path.join( repo_root, 'lib' )
sys.path.insert( 0, lib_dir )
import textDetCore

# %% [markdown]
# # Load Models with Pretrained Weights

# %% [markdown]
# ## 1. scriptID model
#
# The scriptID model's output format is a `nb_samples x 7` array,
# where the 1st dimension stands for the sample axis,
# and the 2nd one stands for the scriptID probability of each known script.
#
# More precisely, the seven scriptID classes are:
#
# | **scriptID index** | **scriptID name** | **Country** |
# |:------------------:|:-----------------:|:-----------:|
# | 0 | NonText | N/A |
# | 1 | Latin | US, UK, etc. |
# | 2 | Hebrew | Israel |
# | 3 | Cyrillic | Russia, Ukraine, etc. |
# | 4 | Arabic | Iran, Saudi Arabia, etc. |
# | 5 | Chinese | China, HongKong, etc. |
# | 6 | TextButUnknown | N/A |

# %%
scriptID_model = textDetCore.create_scriptID_model()
scriptID_model.load_weights( scriptID_weight )
print scriptID_model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# image_in (InputLayer)        (None, None, None, 3)     0
# _________________________________________________________________
# scriptIDb1c1-c (Conv2D)      (None, None, None, 16)    2368
# _________________________________________________________________
# scriptIDb1c1-bn (BatchNormal (None, None, None, 16)    64
# _________________________________________________________________
# scriptIDb1c1-re (Activation) (None, None, None, 16)    0
# _________________________________________________________________
# scriptIDb1c2-c (Conv2D)      (None, None, None, 16)    272
# _________________________________________________________________
# scriptIDb1c2-bn (BatchNormal (None, None, None, 16)    64
# _________________________________________________________________
# scriptIDb1c2-re (Activation) (None, None, None, 16)    0
# _________________________________________________________________
# scriptIDb1c3-c (Conv2D)      (None, None, None, 16)    6416
# _________________________________________________________________
# scriptIDb1c3-bn (BatchNormal (None, None, None, 16)    64
# _________________________________________________________________
# scriptIDb1c3-re (Activation) (None, None, None, 16)    0
# _________________________________________________________________
# scriptIDb1c4-c (Conv2D)      (None, None, None, 16)    272
# _________________________________________________________________
# scriptIDb1c4-bn (BatchNormal (None, None, None, 16)    64
# _________________________________________________________________
# scriptIDb1c4-re (Activation) (None, None, None, 16)    0
# _________________________________________________________________
# scriptIDb1mp (MaxPooling2D)  (None, None, None, 16)    0
# _________________________________________________________________
# scriptIDb2c1-c (Conv2D)      (None, None, None, 32)    4640
# _________________________________________________________________
# scriptIDb2c1-bn (BatchNormal (None, None, None, 32)    128
# _________________________________________________________________
# scriptIDb2c1-re (Activation) (None, None, None, 32)    0
# _________________________________________________________________
# scriptIDb2c2-c (Conv2D)      (None, None, None, 32)    1056
# _________________________________________________________________
# scriptIDb2c2-bn (BatchNormal (None, None, None, 32)    128
# _________________________________________________________________
# scriptIDb2c2-re (Activation) (None, None, None, 32)    0
# _________________________________________________________________
# scriptIDb2c3-c (Conv2D)      (None, None, None, 32)    9248
# _________________________________________________________________
# scriptIDb2c3-bn (BatchNormal (None, None, None, 32)    128
# _________________________________________________________________
# scriptIDb2c3-re (Activation) (None, None, None, 32)    0
# _________________________________________________________________
# scriptIDb2c4-c (Conv2D)      (None, None, None, 32)    1056
# _________________________________________________________________
# scriptIDb2c4-bn (BatchNormal (None, None, None, 32)    128
# _________________________________________________________________
# scriptIDb2c4-re (Activation) (None, None, None, 32)    0
# _________________________________________________________________
# scriptIDb2mp (MaxPooling2D)  (None, None, None, 32)    0
# _________________________________________________________________
# scriptIDb3c1-c (Conv2D)      (None, None, None, 64)    18496
# _________________________________________________________________
# scriptIDb3c1-bn (BatchNormal (None, None, None, 64)    256
# _________________________________________________________________
# scriptIDb3c1-re (Activation) (None, None, None, 64)    0
# _________________________________________________________________
# scriptIDb3c2-c (Conv2D)      (None, None, None, 64)    4160
# _________________________________________________________________
# scriptIDb3c2-bn (BatchNormal (None, None, None, 64)    256
# _________________________________________________________________
# scriptIDb3c2-re (Activation) (None, None, None, 64)    0
# _________________________________________________________________
# scriptIDb3c3-c (Conv2D)      (None, None, None, 64)    36928
# _________________________________________________________________
# scriptIDb3c3-bn (BatchNormal (None, None, None, 64)    256
# _________________________________________________________________
# scriptIDb3c3-re (Activation) (None, None, None, 64)    0
# _________________________________________________________________
# scriptIDb3c4-c (Conv2D)      (None, None, None, 64)    4160
# _________________________________________________________________
# scriptIDb3c4-bn (BatchNormal (None, None, None, 64)    256
# _________________________________________________________________
# scriptIDb3c4-re (Activation) (None, None, None, 64)    0
# _________________________________________________________________
# scriptIDb3mp (MaxPooling2D)  (None, None, None, 64)    0
# _________________________________________________________________
# scriptIDb4c1-c (Conv2D)      (None, None, None, 128)   73856
# _________________________________________________________________
# scriptIDb4c1-bn (BatchNormal (None, None, None, 128)   512
# _________________________________________________________________
# scriptIDb4c1-re (Activation) (None, None, None, 128)   0
# _________________________________________________________________
# scriptIDb4c2-c (Conv2D)      (None, None, None, 128)   16512
# _________________________________________________________________
# scriptIDb4c2-bn (BatchNormal (None, None, None, 128)   512
# _________________________________________________________________
# scriptIDb4c2-re (Activation) (None, None, None, 128)   0
# _________________________________________________________________
# scriptIDb4c3-c (Conv2D)      (None, None, None, 128)   147584
# _________________________________________________________________
# scriptIDb4c3-bn (BatchNormal (None, None, None, 128)   512
# _________________________________________________________________
# scriptIDb4c3-re (Activation) (None, None, None, 128)   0
# _________________________________________________________________
# scriptIDb4c4-c (Conv2D)      (None, None, None, 128)   16512
# _________________________________________________________________
# scriptIDb4c4-bn (BatchNormal (None, None, None, 128)   512
# _________________________________________________________________
# scriptIDb4c4-re (Activation) (None, None, None, 128)   0
# _________________________________________________________________
# scriptIDb4mp (MaxPooling2D)  (None, None, None, 128)   0
# _________________________________________________________________
# scriptIDl2-c1-c (Conv2D)     (None, None, None, 512)   590336
# _________________________________________________________________
# scriptIDl2-c1-bn (BatchNorma (None, None, None, 512)   2048
# _________________________________________________________________
# scriptIDl2-c1-re (Activation (None, None, None, 512)   0
# _________________________________________________________________
# scriptIDl2-c2-c (Conv2D)     (None, None, None, 512)   262656
# _________________________________________________________________
# scriptIDl2-c2-bn (BatchNorma (None, None, None, 512)   2048
# _________________________________________________________________
# scriptIDl2-c2-re (Activation (None, None, None, 512)   0
# _________________________________________________________________
# scriptIDl2-c3-c (Conv2D)     (None, None, None, 512)   2359808
# _________________________________________________________________
# scriptIDl2-c3-bn (BatchNorma (None, None, None, 512)   2048
# _________________________________________________________________
# scriptIDl2-c3-re (Activation (None, None, None, 512)   0
# _________________________________________________________________
# scriptIDl2-c4-c (Conv2D)     (None, None, None, 512)   262656
# _________________________________________________________________
# scriptIDl2-c4-bn (BatchNorma (None, None, None, 512)   2048
# _________________________________________________________________
# scriptIDl2-c4-re (Activation (None, None, None, 512)   0
# _________________________________________________________________
# scriptIDl2-mp (MaxPooling2D) (None, None, None, 512)   0
# _________________________________________________________________
# scriptIDl-pool (GlobalAverag (None, 512)               0
# _________________________________________________________________
# scriptIDl-d1 (Dropout)       (None, 512)               0
# _________________________________________________________________
# scriptIDl-fc1 (Dense)        (None, 128)               65664
# _________________________________________________________________
# scriptIDl-d2 (Dropout)       (None, 128)               0
# _________________________________________________________________
# scriptIDpred (Dense)         (None, 7)                 903
# =================================================================
# Total params: 3,897,591
# Trainable params: 3,891,575
# Non-trainable params: 6,016
# _________________________________________________________________
# None

# %% [markdown]
# # 2. textDet model
# The textDet model's output format is a `nb_samples x height x width x 3` array,
# where the last dimension stands for the text probabilities of
# - non-text/background
# - border
# - text

# %%
textDet_model = textDetCore.create_textDet_model()
textDet_model.load_weights( textDet_weight )
print textDet_model.summary()
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# image_in (InputLayer)            (None, None, None, 3) 0
# ____________________________________________________________________________________________________
# textDetb1c1-c (Conv2D)           (None, None, None, 16 2368        image_in[0][0]
# ____________________________________________________________________________________________________
# textDetb1c1-bn (BatchNormalizati (None, None, None, 16 64          textDetb1c1-c[0][0]
# ____________________________________________________________________________________________________
# textDetb1c1-re (Activation)      (None, None, None, 16 0           textDetb1c1-bn[0][0]
# ____________________________________________________________________________________________________
# textDetb1c2-c (Conv2D)           (None, None, None, 16 272         textDetb1c1-re[0][0]
# ____________________________________________________________________________________________________
# textDetb1c2-bn (BatchNormalizati (None, None, None, 16 64          textDetb1c2-c[0][0]
# ____________________________________________________________________________________________________
# textDetb1c2-re (Activation)      (None, None, None, 16 0           textDetb1c2-bn[0][0]
# ____________________________________________________________________________________________________
# textDetb1c3-c (Conv2D)           (None, None, None, 16 6416        textDetb1c2-re[0][0]
# ____________________________________________________________________________________________________
# textDetb1c3-bn (BatchNormalizati (None, None, None, 16 64          textDetb1c3-c[0][0]
# ____________________________________________________________________________________________________
# textDetb1c3-re (Activation)      (None, None, None, 16 0           textDetb1c3-bn[0][0]
# ____________________________________________________________________________________________________
# textDetb1c4-c (Conv2D)           (None, None, None, 16 272         textDetb1c3-re[0][0]
# ____________________________________________________________________________________________________
# textDetb1c4-bn (BatchNormalizati (None, None, None, 16 64          textDetb1c4-c[0][0]
# ____________________________________________________________________________________________________
# textDetb1c4-re (Activation)      (None, None, None, 16 0           textDetb1c4-bn[0][0]
# ____________________________________________________________________________________________________
# textDetb1mp (MaxPooling2D)       (None, None, None, 16 0           textDetb1c4-re[0][0]
# ____________________________________________________________________________________________________
# textDetb2c1-c (Conv2D)           (None, None, None, 32 4640        textDetb1mp[0][0]
# ____________________________________________________________________________________________________
# textDetb2c1-bn (BatchNormalizati (None, None, None, 32 128         textDetb2c1-c[0][0]
# ____________________________________________________________________________________________________
# textDetb2c1-re (Activation)      (None, None, None, 32 0           textDetb2c1-bn[0][0]
# ____________________________________________________________________________________________________
# textDetb2c2-c (Conv2D)           (None, None, None, 32 1056        textDetb2c1-re[0][0]
# ____________________________________________________________________________________________________
# textDetb2c2-bn (BatchNormalizati (None, None, None, 32 128         textDetb2c2-c[0][0]
# ____________________________________________________________________________________________________
# textDetb2c2-re (Activation)      (None, None, None, 32 0           textDetb2c2-bn[0][0]
# ____________________________________________________________________________________________________
# textDetb2c3-c (Conv2D)           (None, None, None, 32 9248        textDetb2c2-re[0][0]
# ____________________________________________________________________________________________________
# textDetb2c3-bn (BatchNormalizati (None, None, None, 32 128         textDetb2c3-c[0][0]
# ____________________________________________________________________________________________________
# textDetb2c3-re (Activation)      (None, None, None, 32 0           textDetb2c3-bn[0][0]
# ____________________________________________________________________________________________________
# textDetb2c4-c (Conv2D)           (None, None, None, 32 1056        textDetb2c3-re[0][0]
# ____________________________________________________________________________________________________
# textDetb2c4-bn (BatchNormalizati (None, None, None, 32 128         textDetb2c4-c[0][0]
# ____________________________________________________________________________________________________
# textDetb2c4-re (Activation)      (None, None, None, 32 0           textDetb2c4-bn[0][0]
# ____________________________________________________________________________________________________
# textDetb2mp (MaxPooling2D)       (None, None, None, 32 0           textDetb2c4-re[0][0]
# ____________________________________________________________________________________________________
# textDetb3c1-c (Conv2D)           (None, None, None, 64 18496       textDetb2mp[0][0]
# ____________________________________________________________________________________________________
# textDetb3c1-bn (BatchNormalizati (None, None, None, 64 256         textDetb3c1-c[0][0]
# ____________________________________________________________________________________________________
# textDetb3c1-re (Activation)      (None, None, None, 64 0           textDetb3c1-bn[0][0]
# ____________________________________________________________________________________________________
# textDetb3c2-c (Conv2D)           (None, None, None, 64 4160        textDetb3c1-re[0][0]
# ____________________________________________________________________________________________________
# textDetb3c2-bn (BatchNormalizati (None, None, None, 64 256         textDetb3c2-c[0][0]
# ____________________________________________________________________________________________________
# textDetb3c2-re (Activation)      (None, None, None, 64 0           textDetb3c2-bn[0][0]
# ____________________________________________________________________________________________________
# textDetb3c3-c (Conv2D)           (None, None, None, 64 36928       textDetb3c2-re[0][0]
# ____________________________________________________________________________________________________
# textDetb3c3-bn (BatchNormalizati (None, None, None, 64 256         textDetb3c3-c[0][0]
# ____________________________________________________________________________________________________
# textDetb3c3-re (Activation)      (None, None, None, 64 0           textDetb3c3-bn[0][0]
# ____________________________________________________________________________________________________
# textDetb3c4-c (Conv2D)           (None, None, None, 64 4160        textDetb3c3-re[0][0]
# ____________________________________________________________________________________________________
# textDetb3c4-bn (BatchNormalizati (None, None, None, 64 256         textDetb3c4-c[0][0]
# ____________________________________________________________________________________________________
# textDetb3c4-re (Activation)      (None, None, None, 64 0           textDetb3c4-bn[0][0]
# ____________________________________________________________________________________________________
# textDetb3mp (MaxPooling2D)       (None, None, None, 64 0           textDetb3c4-re[0][0]
# ____________________________________________________________________________________________________
# textDetb4c1-c (Conv2D)           (None, None, None, 12 73856       textDetb3mp[0][0]
# ____________________________________________________________________________________________________
# textDetb4c1-bn (BatchNormalizati (None, None, None, 12 512         textDetb4c1-c[0][0]
# ____________________________________________________________________________________________________
# textDetb4c1-re (Activation)      (None, None, None, 12 0           textDetb4c1-bn[0][0]
# ____________________________________________________________________________________________________
# textDetb4c2-c (Conv2D)           (None, None, None, 12 16512       textDetb4c1-re[0][0]
# ____________________________________________________________________________________________________
# textDetb4c2-bn (BatchNormalizati (None, None, None, 12 512         textDetb4c2-c[0][0]
# ____________________________________________________________________________________________________
# textDetb4c2-re (Activation)      (None, None, None, 12 0           textDetb4c2-bn[0][0]
# ____________________________________________________________________________________________________
# textDetb4c3-c (Conv2D)           (None, None, None, 12 147584      textDetb4c2-re[0][0]
# ____________________________________________________________________________________________________
# textDetb4c3-bn (BatchNormalizati (None, None, None, 12 512         textDetb4c3-c[0][0]
# ____________________________________________________________________________________________________
# textDetb4c3-re (Activation)      (None, None, None, 12 0           textDetb4c3-bn[0][0]
# ____________________________________________________________________________________________________
# textDetb4c4-c (Conv2D)           (None, None, None, 12 16512       textDetb4c3-re[0][0]
# ____________________________________________________________________________________________________
# textDetb4c4-bn (BatchNormalizati (None, None, None, 12 512         textDetb4c4-c[0][0]
# ____________________________________________________________________________________________________
# textDetb4c4-re (Activation)      (None, None, None, 12 0           textDetb4c4-bn[0][0]
# ____________________________________________________________________________________________________
# textDetb4mp (MaxPooling2D)       (None, None, None, 12 0           textDetb4c4-re[0][0]
# ____________________________________________________________________________________________________
# textDetd1_c0 (Conv2D)            (None, None, None, 32 4128        textDetb4mp[0][0]
# ____________________________________________________________________________________________________
# textDetd1_c1 (Conv2D)            (None, None, None, 32 36896       textDetb4mp[0][0]
# ____________________________________________________________________________________________________
# textDetd1_merge (Concatenate)    (None, None, None, 64 0           textDetd1_c0[0][0]
#                                                                    textDetd1_c1[0][0]
# ____________________________________________________________________________________________________
# textDetd1_bn (BatchNormalization (None, None, None, 64 256         textDetd1_merge[0][0]
# ____________________________________________________________________________________________________
# textDetd1_re (Activation)        (None, None, None, 64 0           textDetd1_bn[0][0]
# ____________________________________________________________________________________________________
# textDetd1x2 (BilinearUpSampling) (None, None, None, 64 0           textDetd1_re[0][0]
# ____________________________________________________________________________________________________
# textDetd2_c0 (Conv2D)            (None, None, None, 24 13848       textDetd1x2[0][0]
# ____________________________________________________________________________________________________
# textDetd2_c1 (Conv2D)            (None, None, None, 24 38424       textDetd1x2[0][0]
# ____________________________________________________________________________________________________
# textDetd2_merge (Concatenate)    (None, None, None, 48 0           textDetd2_c0[0][0]
#                                                                    textDetd2_c1[0][0]
# ____________________________________________________________________________________________________
# textDetd2_bn (BatchNormalization (None, None, None, 48 192         textDetd2_merge[0][0]
# ____________________________________________________________________________________________________
# textDetd2_re (Activation)        (None, None, None, 48 0           textDetd2_bn[0][0]
# ____________________________________________________________________________________________________
# textDetd2x2 (BilinearUpSampling) (None, None, None, 48 0           textDetd2_re[0][0]
# ____________________________________________________________________________________________________
# textDetd3_c0 (Conv2D)            (None, None, None, 16 19216       textDetd2x2[0][0]
# ____________________________________________________________________________________________________
# textDetd3_c1 (Conv2D)            (None, None, None, 16 37648       textDetd2x2[0][0]
# ____________________________________________________________________________________________________
# textDetd3_merge (Concatenate)    (None, None, None, 32 0           textDetd3_c0[0][0]
#                                                                    textDetd3_c1[0][0]
# ____________________________________________________________________________________________________
# textDetd3_bn (BatchNormalization (None, None, None, 32 128         textDetd3_merge[0][0]
# ____________________________________________________________________________________________________
# textDetd3_re (Activation)        (None, None, None, 32 0           textDetd3_bn[0][0]
# ____________________________________________________________________________________________________
# textDetd3x2 (BilinearUpSampling) (None, None, None, 32 0           textDetd3_re[0][0]
# ____________________________________________________________________________________________________
# textDetd4_c0 (Conv2D)            (None, None, None, 8) 2312        textDetd3x2[0][0]
# ____________________________________________________________________________________________________
# textDetd4_c1 (Conv2D)            (None, None, None, 8) 6408        textDetd3x2[0][0]
# ____________________________________________________________________________________________________
# textDetd4_c2 (Conv2D)            (None, None, None, 8) 12552       textDetd3x2[0][0]
# ____________________________________________________________________________________________________
# textDetd4_merge (Concatenate)    (None, None, None, 24 0           textDetd4_c0[0][0]
#                                                                    textDetd4_c1[0][0]
#                                                                    textDetd4_c2[0][0]
# ____________________________________________________________________________________________________
# textDetd4_bn (BatchNormalization (None, None, None, 24 96          textDetd4_merge[0][0]
# ____________________________________________________________________________________________________
# textDetd4_re (Activation)        (None, None, None, 24 0           textDetd4_bn[0][0]
# ____________________________________________________________________________________________________
# textDetd4x2 (BilinearUpSampling) (None, None, None, 24 0           textDetd4_re[0][0]
# ____________________________________________________________________________________________________
# textDetd5_c0 (Conv2D)            (None, None, None, 4) 868         textDetd4x2[0][0]
# ____________________________________________________________________________________________________
# textDetd5_c1 (Conv2D)            (None, None, None, 4) 2404        textDetd4x2[0][0]
# ____________________________________________________________________________________________________
# textDetd5_c2 (Conv2D)            (None, None, None, 4) 4708        textDetd4x2[0][0]
# ____________________________________________________________________________________________________
# textDetd5_c3 (Conv2D)            (None, None, None, 4) 7780        textDetd4x2[0][0]
# ____________________________________________________________________________________________________
# textDetd5_merge (Concatenate)    (None, None, None, 16 0           textDetd5_c0[0][0]
#                                                                    textDetd5_c1[0][0]
#                                                                    textDetd5_c2[0][0]
#                                                                    textDetd5_c3[0][0]
# ____________________________________________________________________________________________________
# textDetd5_bn (BatchNormalization (None, None, None, 16 64          textDetd5_merge[0][0]
# ____________________________________________________________________________________________________
# textDetd5_re (Activation)        (None, None, None, 16 0           textDetd5_bn[0][0]
# ____________________________________________________________________________________________________
# textDetpred (Conv2D)             (None, None, None, 3) 5811        textDetd5_re[0][0]
# ====================================================================================================
# Total params: 541,115
# Trainable params: 538,827
# Non-trainable params: 2,288
# ____________________________________________________________________________________________________
# None

# %% [markdown]
# # Load Pre- and Post- Utils

# %%
# 1. non-mandatory utils
from textDetUtils import read_image, bwlabel, decode_text_bboxes, visualize_text_proba_map, visualize_individual_regions
import pandas as pd
# 2. mandatory utils
from textDetUtils import convert_imageArray_to_inputTensor, decode_scriptID

# %% [markdown]
# ## Sample Decoder
#
# Both TextDet and ScriptID models provide raw results, it, therefore, requires necessary post-processing to convert these raw outputs to a desired format. Below we provide a simple decoder supporting the features:
#
# 1. read image from a file path or a web-link
# 2. resize an image
# 3. thresholds to reject low confident text regions in terms of
#     - text region size
#     - text probability
# 4. locate each indiviudal text region and rectify it
# 5. identify the dominant script ID for an image or each individual text region
# 6. visualize text probability map and all rectified regions
#
# Feel free to add new features to this simple decoder, e.g.
# - dump rectified region image to disk
# - save detection info, including region bounding box, text probability, scriptID probability, etc.
#
# **NOTE**: The provided decoder is a very basic one, and it can be improved at least in the following aspects:
# 1. self adaptive resize factor: Our training data is dominant by samples with line height in range (20,30) pixel. It is possible to make a two-pass decoder, where the 1st pass is to estimate the page line height, and the 2nd pass is to repropress the adjusted input.
# 2. better text region identification: The simple decoder only uses the simplest connected component analysis on the text-class map (blue pixels in a text detector output). However, the border-class map (green pixels in a text detector output) is also very useful, especially in separating adjacent text regions.

# %%
def simple_decoder( file_path, 
                    textDet_model,
                    scriptID_model,
                    resize_factor = 2.,
                    proba_threshold = .33,
                    area_threshold = 100.,
                    visualize = True ) :
    # 1. read image
    img = read_image( file_path )
    # 1.b resize image if necessary
    ih, iw = img.shape[:2]
    if ( resize_factor != 1 ) :
        nh, nw = int(ih*resize_factor), int(iw*resize_factor)
        img = cv2.resize( img, (nw, nh) )
    # 2. convert input image to network tensor
    ih, iw = img.shape[:2]
    x = convert_imageArray_to_inputTensor( img )
    # 3. predict text probability map
    text_proba  = textDet_model.predict(x)
    text_proba = text_proba[0] # since we always take one sample at a time
    # 3.b sample connected component analysis based decoder
    membership = text_proba.argmax( axis = -1 )
    regions = bwlabel( membership == 2, neighbors=8 )
    decoded_results = decode_text_bboxes( img, text_proba[...,-1], regions )
    # 4. predict script ID
    script_proba = scriptID_model.predict(x[:,::2,::2])
    scriptID = decode_scriptID( script_proba )[0]
    # 5. visualize results
    if ( visualize ) :
        visualize_text_proba_map( img, text_proba[:ih,:iw], scriptID )
        visualize_individual_regions( decoded_results, proba_threshold, area_threshold  )
    # 6. save detection results 
    # modify this section to save additional/different information
    header = ','.join([ 'topLeftX', 'topLeftY', 'botRightX', 'botRightY', 'boxProba' ])
    det_results = [ header ]
    for idx, (bbox, proba, wrapped_image) in enumerate( decoded_results ):
        if ( proba < proba_threshold ) :
            continue
        upper_left, upper_right, lower_right, lower_left = bbox
        area = np.product( lower_right - upper_left )
        if ( area < area_threshold ) :
            continue
        upper_left = [ '{:d}'.format(int(val/resize_factor)) for val in upper_left ]
        lower_right = [ '{:d}'.format(int(val/resize_factor)) for val in lower_right ]
        this_line = upper_left + lower_right + [ '{:.3f}'.format(proba) ]
        this_line = ','.join( this_line )
        det_results.append( this_line )
    det_results = '\n'.join( det_results )
    return det_results

# %% [markdown]
# # Text and scriptID detection for a web image

# %%
url = 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRSnHUc4igGIJaH0iPFsIsWpFGk2VZcfghhLQ3mg_4cdXxrSagS'
det_results = simple_decoder( file_path,
                              textDet_model,
                              scriptID_model,
                              resize_factor = 2,
                              proba_threshold = .5,
                              area_threshold = 100.,
                              visualize = True )
print det_results
# Out:
# topLeftX,topLeftY,botRightX,botRightY,boxProba
# 93,119,256,169,0.874
# 81,160,260,207,0.851
# 112,207,240,241,0.878

# %% [markdown]
# # Text and scriptID detection for a local image

# %%
file_path = os.path.join( data_dir, 'JAP_atomu-tanaka-japanese-cover-letter-1-638.jpg' )
det_results = simple_decoder( file_path,
                              textDet_model,
                              scriptID_model,
                              resize_factor = 2,
                              proba_threshold = .5,
                              area_threshold = 100.,
                              visualize = True )
# Out:
# /nfs/isicvlnas01/share/anaconda/lib/python2.7/site-packages/matplotlib/pyplot.py:524: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# INFO: skip 78 proba = 0.382915 area = 6
# INFO: skip 79 proba = 0.342357 area = 3
# INFO: skip 80 proba = 0.387955 area = 13
# INFO: skip 81 proba = 0.342428 area = 7
# INFO: skip 82 proba = 0.396578 area = 16

# %% [markdown]
# # Remark
#
# Though you see fancy perspective transform based corrections for text regions, they are not included in `det_results`.  Actually, `det_results` only include rectangular text bounding boxes.
